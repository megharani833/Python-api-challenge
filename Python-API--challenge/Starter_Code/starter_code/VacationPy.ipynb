# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import geoviews as gv

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# C:\Users\suraj\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0      port mathurin -19.6833   63.4167     72.81        77
# 1        1          adamstown -25.0660 -130.1015     69.73        64
# 2        2             murgab  37.4966   61.9714     65.61        27
# 3        3  port-aux-francais -49.3500   70.2167     35.22        69
# 4        4         luganville -15.5333  167.1667     76.03        75
#
#    Cloudiness  Wind Speed Country        Date
# 0          66       18.03      MU  1695849255
# 1          96        7.38      PN  1695849255
# 2          39        8.12      TM  1695849256
# 3          70       30.58      TF  1695849256
# 4          97       12.33      VU  1695849256

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity = data_df["Humidity"].astype(int)

map_plot_1 = data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
city_data_df = data_df.loc[(data_df["Max Temp"] < 80) & (data_df["Max Temp"] > 70)]

city_data_df = city_data_df.loc[(city_data_df["Wind Speed"] < 4.5)]

#city_data_df = city_data_df.loc[(city_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
city_data_df = city_data_df.dropna()


# Display sample data
city_data_df
# Out:
#      City_ID            City      Lat       Lng  Max Temp  Humidity  \
# 6          6            tura  25.5198   90.2201     74.12        91
# 55        55      sarupathar  26.1984   93.8094     75.74        94
# 71        71          nabire  -3.3667  135.4833     75.94        93
# 86        86  carolina beach  34.0352  -77.8936     73.08        78
# 105      105          hasaki  35.7333  140.8333     75.29        88
# 118      118          inongo  -1.9500   18.2667     72.72        92
# 128      128       gaigeturi  33.4644  126.3183     73.45        88
# 148      148           agaie   9.0167    6.3167     78.73        88
# 160      160            taro  -8.3862  115.2800     71.60        91
# 168      168         abepura  -2.6333  140.5833     76.01        88
# 170      170     bamor kalan  24.9000   78.1500     78.10        70
# 176      176          tshela  -4.9833   12.9333     74.12        87
# 196      196          koubia  11.5833  -11.9000     71.24        93
# 216      216         kirando  -7.4167   30.6000     79.45        55
# 269      269          pandan  14.0453  124.1694     79.47        86
# 290      290           arawa  -6.2132  155.5367     76.89        94
# 291      291            miri   4.4148  114.0089     77.54        86
# 294      294            tezu  27.9167   96.1667     76.42        76
# 313      313         toliara -23.3500   43.6667     72.45        84
# 328      328          tumpat   6.1978  102.1710     75.18        94
# 335      335           miura  35.1400  139.6192     76.59        91
# 336      336          boende  -0.2167   20.8667     72.57        94
# 352      352         tympaki  35.0729   24.7685     70.77        86
# 353      353          pihani  27.6333   80.2000     78.24        71
# 366      366      kota bharu   6.1333  102.2386     75.15        94
# 368      368           dumai   1.6833  101.4500     72.97        85
# 390      390           oyama  36.3000  139.8000     78.58        78
# 395      395       gorontalo   0.5412  123.0595     72.21        89
# 435      435         koungou -12.7336   45.2042     74.91        88
# 440      440         shangyu  30.0156  120.8711     78.75        94
# 442      442         buldana  20.5333   76.1833     73.69        85
# 443      443           kimbo  10.4000  -13.5500     70.48        92
# 451      451          sinfra   6.6167   -5.9167     73.11        98
# 452      452           okeho   8.0333    3.3500     74.07        93
# 490      490         barjala  23.6167   91.3667     78.75        86
# 494      494      popondetta  -8.7537  148.2534     73.45        92
# 510      510         guaruja -23.9931  -46.2564     78.66        94
# 520      520       manokwari  -0.8667  134.0833     77.90        79
# 525      525         baganga   7.5739  126.5600     78.15        84
# 544      544         batouri   4.4333   14.3667     70.02        95
# 546      546             pyu  18.4833   96.4333     75.79        99
# 550      550          padang  -0.9492  100.3543     71.65        89
# 551      551         daoukro   7.0591   -3.9631     74.14        97
# 565      565         cho dok  10.7000  105.1167     77.86        88
#
#      Cloudiness  Wind Speed Country        Date
# 6             7        3.89      IN  1695849257
# 55            3        0.47      IN  1695849440
# 71           96        4.27      ID  1695849444
# 86          100        1.01      US  1695849403
# 105          75        3.98      JP  1695849452
# 118         100        3.91      CD  1695849455
# 128         100        1.14      KR  1695849457
# 148         100        2.15      NG  1695849462
# 160          86        2.98      ID  1695849464
# 168          40        0.00      ID  1695849466
# 170           3        0.81      IN  1695849466
# 176           6        3.06      CD  1695849467
# 196         100        1.59      GN  1695849471
# 216          77        2.95      TZ  1695849475
# 269          65        3.47      PH  1695849487
# 290         100        2.86      PG  1695849492
# 291          34        3.85      MY  1695849493
# 294           7        2.98      IN  1695849493
# 313          56        1.77      MG  1695849498
# 328          20        2.30      MY  1695849501
# 335          20        1.10      JP  1695849503
# 336         100        0.98      CD  1695849503
# 352          14        1.99      GR  1695849507
# 353           0        3.29      IN  1695849508
# 366          20        2.30      MY  1695849511
# 368          38        3.29      ID  1695849511
# 390          75        0.74      JP  1695849516
# 395          90        4.38      ID  1695849517
# 435           0        2.30      YT  1695849526
# 440           4        1.45      CN  1695849426
# 442         100        2.42      IN  1695849527
# 443         100        1.77      GN  1695849528
# 451          16        3.02      CI  1695849530
# 452          59        4.25      NG  1695849530
# 490          42        1.14      IN  1695849540
# 494          92        1.66      PG  1695849541
# 510          20        2.30      BR  1695849545
# 520         100        4.29      ID  1695849547
# 525          71        4.47      PH  1695849548
# 544          67        0.40      CM  1695849553
# 546         100        3.76      MM  1695849553
# 550          52        3.69      ID  1695849554
# 551          35        2.51      CI  1695849554
# 565         100        3.91      VN  1695849557

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
city = city_data_df["City"]
country = city_data_df["Country"]
lat = city_data_df["Lat"]
lng = city_data_df["Lng"]
humidity = city_data_df["Humidity"]

hotel_df = city_data_df[{"City": city,
                        "Country": country,
                        "Lat": lat,
                        "Lng": lng,
                        "Humidity": humidity}]



# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
# C:\Users\suraj\AppData\Local\Temp\ipykernel_33412\552856387.py:8: FutureWarning: Passing a dict as an indexer is deprecated and will raise in a future version. Use a list instead.
#   hotel_df = city_data_df[{"City": city,
# C:\Users\suraj\AppData\Local\Temp\ipykernel_33412\552856387.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hotel_df["Hotel Name"] = ""
#                City Country      Lat       Lng  Humidity Hotel Name
# 6              tura      IN  25.5198   90.2201        91
# 55       sarupathar      IN  26.1984   93.8094        94
# 71           nabire      ID  -3.3667  135.4833        93
# 86   carolina beach      US  34.0352  -77.8936        78
# 105          hasaki      JP  35.7333  140.8333        88
# 118          inongo      CD  -1.9500   18.2667        92
# 128       gaigeturi      KR  33.4644  126.3183        88
# 148           agaie      NG   9.0167    6.3167        88
# 160            taro      ID  -8.3862  115.2800        91
# 168         abepura      ID  -2.6333  140.5833        88
# 170     bamor kalan      IN  24.9000   78.1500        70
# 176          tshela      CD  -4.9833   12.9333        87
# 196          koubia      GN  11.5833  -11.9000        93
# 216         kirando      TZ  -7.4167   30.6000        55
# 269          pandan      PH  14.0453  124.1694        86
# 290           arawa      PG  -6.2132  155.5367        94
# 291            miri      MY   4.4148  114.0089        86
# 294            tezu      IN  27.9167   96.1667        76
# 313         toliara      MG -23.3500   43.6667        84
# 328          tumpat      MY   6.1978  102.1710        94
# 335           miura      JP  35.1400  139.6192        91
# 336          boende      CD  -0.2167   20.8667        94
# 352         tympaki      GR  35.0729   24.7685        86
# 353          pihani      IN  27.6333   80.2000        71
# 366      kota bharu      MY   6.1333  102.2386        94
# 368           dumai      ID   1.6833  101.4500        85
# 390           oyama      JP  36.3000  139.8000        78
# 395       gorontalo      ID   0.5412  123.0595        89
# 435         koungou      YT -12.7336   45.2042        88
# 440         shangyu      CN  30.0156  120.8711        94
# 442         buldana      IN  20.5333   76.1833        85
# 443           kimbo      GN  10.4000  -13.5500        92
# 451          sinfra      CI   6.6167   -5.9167        98
# 452           okeho      NG   8.0333    3.3500        93
# 490         barjala      IN  23.6167   91.3667        86
# 494      popondetta      PG  -8.7537  148.2534        92
# 510         guaruja      BR -23.9931  -46.2564        94
# 520       manokwari      ID  -0.8667  134.0833        79
# 525         baganga      PH   7.5739  126.5600        84
# 544         batouri      CM   4.4333   14.3667        95
# 546             pyu      MM  18.4833   96.4333        99
# 550          padang      ID  -0.9492  100.3543        89
# 551         daoukro      CI   7.0591   -3.9631        97
# 565         cho dok      VN  10.7000  105.1167        88

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
     "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tura - nearest hotel: No hotel found
# sarupathar - nearest hotel: No hotel found
# nabire - nearest hotel: Hotel Anggrek
# carolina beach - nearest hotel: Carolina Beach Inn
# hasaki - nearest hotel: 大新旅館
# inongo - nearest hotel: Chez LELE IYOLO
# gaigeturi - nearest hotel: 제주 토비스콘도
# agaie - nearest hotel: No hotel found
# taro - nearest hotel: Padma Resort Ubud
# abepura - nearest hotel: Yoyo
# bamor kalan - nearest hotel: No hotel found
# tshela - nearest hotel: No hotel found
# koubia - nearest hotel: No hotel found
# kirando - nearest hotel: Lakeshore Lodge
# pandan - nearest hotel: No hotel found
# arawa - nearest hotel: No hotel found
# miri - nearest hotel: Kenyalang Suites Miri
# tezu - nearest hotel: No hotel found
# toliara - nearest hotel: Ambary
# tumpat - nearest hotel: Budget 118 Inn
# miura - nearest hotel: 岬陽館
# boende - nearest hotel: Hotel Reference
# tympaki - nearest hotel: Sifogiannis
# pihani - nearest hotel: No hotel found
# kota bharu - nearest hotel: Mizwar Inn Hotel
# dumai - nearest hotel: Comfort Hotel
# oyama - nearest hotel: 東横イン 小山駅東口1
# gorontalo - nearest hotel: Grand City Hotel
# koungou - nearest hotel: Hôtel Trévani
# shangyu - nearest hotel: ShangYu Radisson Hotel
# buldana - nearest hotel: No hotel found
# kimbo - nearest hotel: Hôtel le Pavillon
# sinfra - nearest hotel: Complexe wilson
# okeho - nearest hotel: No hotel found
# barjala - nearest hotel: No hotel found
# popondetta - nearest hotel: No hotel found
# guaruja - nearest hotel: Ferrareto Hotel
# manokwari - nearest hotel: Hotel Arfak
# baganga - nearest hotel: RGD Inn
# batouri - nearest hotel: No hotel found
# pyu - nearest hotel: KMA
# padang - nearest hotel: losmen Surya
# daoukro - nearest hotel: Hôtel BEKANTI
# cho dok - nearest hotel: KS Hoàng Tuyên
#                City Country      Lat       Lng  Humidity  \
# 6              tura      IN  25.5198   90.2201        91
# 55       sarupathar      IN  26.1984   93.8094        94
# 71           nabire      ID  -3.3667  135.4833        93
# 86   carolina beach      US  34.0352  -77.8936        78
# 105          hasaki      JP  35.7333  140.8333        88
# 118          inongo      CD  -1.9500   18.2667        92
# 128       gaigeturi      KR  33.4644  126.3183        88
# 148           agaie      NG   9.0167    6.3167        88
# 160            taro      ID  -8.3862  115.2800        91
# 168         abepura      ID  -2.6333  140.5833        88
# 170     bamor kalan      IN  24.9000   78.1500        70
# 176          tshela      CD  -4.9833   12.9333        87
# 196          koubia      GN  11.5833  -11.9000        93
# 216         kirando      TZ  -7.4167   30.6000        55
# 269          pandan      PH  14.0453  124.1694        86
# 290           arawa      PG  -6.2132  155.5367        94
# 291            miri      MY   4.4148  114.0089        86
# 294            tezu      IN  27.9167   96.1667        76
# 313         toliara      MG -23.3500   43.6667        84
# 328          tumpat      MY   6.1978  102.1710        94
# 335           miura      JP  35.1400  139.6192        91
# 336          boende      CD  -0.2167   20.8667        94
# 352         tympaki      GR  35.0729   24.7685        86
# 353          pihani      IN  27.6333   80.2000        71
# 366      kota bharu      MY   6.1333  102.2386        94
# 368           dumai      ID   1.6833  101.4500        85
# 390           oyama      JP  36.3000  139.8000        78
# 395       gorontalo      ID   0.5412  123.0595        89
# 435         koungou      YT -12.7336   45.2042        88
# 440         shangyu      CN  30.0156  120.8711        94
# 442         buldana      IN  20.5333   76.1833        85
# 443           kimbo      GN  10.4000  -13.5500        92
# 451          sinfra      CI   6.6167   -5.9167        98
# 452           okeho      NG   8.0333    3.3500        93
# 490         barjala      IN  23.6167   91.3667        86
# 494      popondetta      PG  -8.7537  148.2534        92
# 510         guaruja      BR -23.9931  -46.2564        94
# 520       manokwari      ID  -0.8667  134.0833        79
# 525         baganga      PH   7.5739  126.5600        84
# 544         batouri      CM   4.4333   14.3667        95
# 546             pyu      MM  18.4833   96.4333        99
# 550          padang      ID  -0.9492  100.3543        89
# 551         daoukro      CI   7.0591   -3.9631        97
# 565         cho dok      VN  10.7000  105.1167        88
#
#                  Hotel Name
# 6            No hotel found
# 55           No hotel found
# 71            Hotel Anggrek
# 86       Carolina Beach Inn
# 105                    大新旅館
# 118         Chez LELE IYOLO
# 128                제주 토비스콘도
# 148          No hotel found
# 160       Padma Resort Ubud
# 168                    Yoyo
# 170          No hotel found
# 176          No hotel found
# 196          No hotel found
# 216         Lakeshore Lodge
# 269          No hotel found
# 290          No hotel found
# 291   Kenyalang Suites Miri
# 294          No hotel found
# 313                  Ambary
# 328          Budget 118 Inn
# 335                     岬陽館
# 336         Hotel Reference
# 352             Sifogiannis
# 353          No hotel found
# 366        Mizwar Inn Hotel
# 368           Comfort Hotel
# 390             東横イン 小山駅東口1
# 395        Grand City Hotel
# 435           Hôtel Trévani
# 440  ShangYu Radisson Hotel
# 442          No hotel found
# 443       Hôtel le Pavillon
# 451         Complexe wilson
# 452          No hotel found
# 490          No hotel found
# 494          No hotel found
# 510         Ferrareto Hotel
# 520             Hotel Arfak
# 525                 RGD Inn
# 544          No hotel found
# 546                     KMA
# 550            losmen Surya
# 551           Hôtel BEKANTI
# 565          KS Hoàng Tuyên

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
     "categories": "accommodation.hotel",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# tura - nearest hotel: No hotel found
# sarupathar - nearest hotel: No hotel found
# nabire - nearest hotel: Hotel Anggrek
# carolina beach - nearest hotel: Carolina Beach Inn
# hasaki - nearest hotel: 大新旅館
# inongo - nearest hotel: Chez LELE IYOLO
# gaigeturi - nearest hotel: 제주 토비스콘도
# agaie - nearest hotel: No hotel found
# taro - nearest hotel: Padma Resort Ubud
# abepura - nearest hotel: Yoyo
# bamor kalan - nearest hotel: No hotel found
# tshela - nearest hotel: No hotel found
# koubia - nearest hotel: No hotel found
# kirando - nearest hotel: Lakeshore Lodge
# pandan - nearest hotel: No hotel found
# arawa - nearest hotel: No hotel found
# miri - nearest hotel: Kenyalang Suites Miri
# tezu - nearest hotel: No hotel found
# toliara - nearest hotel: Ambary
# tumpat - nearest hotel: Budget 118 Inn
# miura - nearest hotel: 岬陽館
# boende - nearest hotel: Hotel Reference
# tympaki - nearest hotel: Sifogiannis
# pihani - nearest hotel: No hotel found
# kota bharu - nearest hotel: Mizwar Inn Hotel
# dumai - nearest hotel: Comfort Hotel
# oyama - nearest hotel: 東横イン 小山駅東口1
# gorontalo - nearest hotel: Grand City Hotel
# koungou - nearest hotel: Hôtel Trévani
# shangyu - nearest hotel: ShangYu Radisson Hotel
# buldana - nearest hotel: No hotel found
# kimbo - nearest hotel: Hôtel le Pavillon
# sinfra - nearest hotel: Complexe wilson
# okeho - nearest hotel: No hotel found
# barjala - nearest hotel: No hotel found
# popondetta - nearest hotel: No hotel found
# guaruja - nearest hotel: Ferrareto Hotel
# manokwari - nearest hotel: Hotel Arfak
# baganga - nearest hotel: RGD Inn
# batouri - nearest hotel: No hotel found
# pyu - nearest hotel: KMA
# padang - nearest hotel: losmen Surya
# daoukro - nearest hotel: Hôtel BEKANTI
# cho dok - nearest hotel: KS Hoàng Tuyên
#                City Country      Lat       Lng  Humidity  \
# 6              tura      IN  25.5198   90.2201        91
# 55       sarupathar      IN  26.1984   93.8094        94
# 71           nabire      ID  -3.3667  135.4833        93
# 86   carolina beach      US  34.0352  -77.8936        78
# 105          hasaki      JP  35.7333  140.8333        88
# 118          inongo      CD  -1.9500   18.2667        92
# 128       gaigeturi      KR  33.4644  126.3183        88
# 148           agaie      NG   9.0167    6.3167        88
# 160            taro      ID  -8.3862  115.2800        91
# 168         abepura      ID  -2.6333  140.5833        88
# 170     bamor kalan      IN  24.9000   78.1500        70
# 176          tshela      CD  -4.9833   12.9333        87
# 196          koubia      GN  11.5833  -11.9000        93
# 216         kirando      TZ  -7.4167   30.6000        55
# 269          pandan      PH  14.0453  124.1694        86
# 290           arawa      PG  -6.2132  155.5367        94
# 291            miri      MY   4.4148  114.0089        86
# 294            tezu      IN  27.9167   96.1667        76
# 313         toliara      MG -23.3500   43.6667        84
# 328          tumpat      MY   6.1978  102.1710        94
# 335           miura      JP  35.1400  139.6192        91
# 336          boende      CD  -0.2167   20.8667        94
# 352         tympaki      GR  35.0729   24.7685        86
# 353          pihani      IN  27.6333   80.2000        71
# 366      kota bharu      MY   6.1333  102.2386        94
# 368           dumai      ID   1.6833  101.4500        85
# 390           oyama      JP  36.3000  139.8000        78
# 395       gorontalo      ID   0.5412  123.0595        89
# 435         koungou      YT -12.7336   45.2042        88
# 440         shangyu      CN  30.0156  120.8711        94
# 442         buldana      IN  20.5333   76.1833        85
# 443           kimbo      GN  10.4000  -13.5500        92
# 451          sinfra      CI   6.6167   -5.9167        98
# 452           okeho      NG   8.0333    3.3500        93
# 490         barjala      IN  23.6167   91.3667        86
# 494      popondetta      PG  -8.7537  148.2534        92
# 510         guaruja      BR -23.9931  -46.2564        94
# 520       manokwari      ID  -0.8667  134.0833        79
# 525         baganga      PH   7.5739  126.5600        84
# 544         batouri      CM   4.4333   14.3667        95
# 546             pyu      MM  18.4833   96.4333        99
# 550          padang      ID  -0.9492  100.3543        89
# 551         daoukro      CI   7.0591   -3.9631        97
# 565         cho dok      VN  10.7000  105.1167        88
#
#                  Hotel Name
# 6            No hotel found
# 55           No hotel found
# 71            Hotel Anggrek
# 86       Carolina Beach Inn
# 105                    大新旅館
# 118         Chez LELE IYOLO
# 128                제주 토비스콘도
# 148          No hotel found
# 160       Padma Resort Ubud
# 168                    Yoyo
# 170          No hotel found
# 176          No hotel found
# 196          No hotel found
# 216         Lakeshore Lodge
# 269          No hotel found
# 290          No hotel found
# 291   Kenyalang Suites Miri
# 294          No hotel found
# 313                  Ambary
# 328          Budget 118 Inn
# 335                     岬陽館
# 336         Hotel Reference
# 352             Sifogiannis
# 353          No hotel found
# 366        Mizwar Inn Hotel
# 368           Comfort Hotel
# 390             東横イン 小山駅東口1
# 395        Grand City Hotel
# 435           Hôtel Trévani
# 440  ShangYu Radisson Hotel
# 442          No hotel found
# 443       Hôtel le Pavillon
# 451         Complexe wilson
# 452          No hotel found
# 490          No hotel found
# 494          No hotel found
# 510         Ferrareto Hotel
# 520             Hotel Arfak
# 525                 RGD Inn
# 544          No hotel found
# 546                     KMA
# 550            losmen Surya
# 551           Hôtel BEKANTI
# 565          KS Hoàng Tuyên

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75,
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
